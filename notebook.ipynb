# %%
from core.llmcodes.Chunk import PDFProcessor
from core.vector_store import chroma_client
pdf_processor = PDFProcessor(chromadb_client=chroma_client, chat_id=123, file_path=r"C:\Users\mrami\Desktop\Async\Async-document-processing-API\uploads\CV.pdf")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from core.llmcodes.Chunk import PDFProcessor
#       2 from core.vector_store import chroma_client
#       3 pdf_processor = PDFProcessor(chromadb_client=chroma_client, chat_id=123, file_path=r"C:\Users\mrami\Desktop\Async\Async-document-processing-API\uploads\CV.pdf")
#
# File c:\Users\mrami\Desktop\Async\Async-document-processing-API\core\llmcodes\Chunk.py:4
#       2 import chromadb
#       3 from chromadb.utils.embedding_functions import GoogleGeminiEmbeddingFunction
# ----> 4 from langchain_community.document_loaders import PyPDFLoader
#       5 from langchain_text_splitters import RecursiveCharacterTextSplitter
#       7 class PDFProcessor:
#
# File <frozen importlib._bootstrap>:1412, in _handle_fromlist(module, fromlist, import_, recursive)
#
# ...
